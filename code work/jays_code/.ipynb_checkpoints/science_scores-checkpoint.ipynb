# %%
# %matplotlib inline
import pandas as pd

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import mpld3
mpld3.enable_notebook()


path= '../data/science_10_15.csv'
science_df =  pd.read_csv(path)
# science_df
# Out:
#    LOCATION    INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value  Flag Codes
# 0       CAN  PISASCIENCE     TOT  MEANSCORE         A  2012    525         NaN
# 1       CAN  PISASCIENCE     TOT  MEANSCORE         A  2015    528         NaN
# 2       FIN  PISASCIENCE     TOT  MEANSCORE         A  2012    545         NaN
# 3       FIN  PISASCIENCE     TOT  MEANSCORE         A  2015    531         NaN
# 4       FRA  PISASCIENCE     TOT  MEANSCORE         A  2012    499         NaN
# 5       FRA  PISASCIENCE     TOT  MEANSCORE         A  2015    495         NaN
# 6       DEU  PISASCIENCE     TOT  MEANSCORE         A  2012    524         NaN
# 7       DEU  PISASCIENCE     TOT  MEANSCORE         A  2015    509         NaN
# 8       JPN  PISASCIENCE     TOT  MEANSCORE         A  2012    547         NaN
# 9       JPN  PISASCIENCE     TOT  MEANSCORE         A  2015    538         NaN
# 10      KOR  PISASCIENCE     TOT  MEANSCORE         A  2012    538         NaN
# ...

# %%
clean_sci = science_df.drop(['Flag Codes'], axis=1)
