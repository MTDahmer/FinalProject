# %%
# %matplotlib inline
import pandas as pd

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import mpld3
mpld3.enable_notebook()


filepath= '../data/ed_spending_per_student_10-15.csv'
data =  pd.read_csv(filepath)
data.head()
# Out:
#   LOCATION INDICATOR   SUBJECT      MEASURE FREQUENCY  TIME      Value  \
# 0      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9950.004
# 1      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011  10000.179
# 2      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012  10398.065
# 3      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013  10535.674
# 4      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014  10501.547
#
#   Flag Codes
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
new_data = data.drop(['Flag Codes'], axis=1)

# %%
data_new = new_data.dropna()
data_new.head()
# Out:
#   LOCATION INDICATOR   SUBJECT      MEASURE FREQUENCY  TIME      Value
# 0      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9950.004
# 1      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011  10000.179
# 2      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012  10398.065
# 3      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013  10535.674
# 4      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014  10501.547

# %%
# data_new.to_csv('../clean_data/ED_doller_10-15.csv', index=False)

# %%
df_time = data_new.groupby(['TIME'])

# %%
df_country = data_new.groupby(['LOCATION'])

# %%
df_country.first()
# Out:
#          INDICATOR   SUBJECT      MEASURE FREQUENCY  TIME      Value
# LOCATION
# CAN         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9950.004
# DEU         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9203.307
# FIN         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   8834.754
# FRA         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9265.066
# GBR         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9431.662
# JPN         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   8885.861
# KOR         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9122.943
# MEX         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   2546.722
# USA         EDUEXP  PRY_NTRY  USD_STUDENT         A  2010  11814.530

# %%
df_time.first()
# Out:
#      LOCATION INDICATOR   SUBJECT      MEASURE FREQUENCY      Value
# TIME
# 2010      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A   9950.004
# 2011      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  10000.179
# 2012      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  10398.065
# 2013      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  10535.674
# 2014      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  10501.547
# 2015      CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  10467.831

# %%
 df_10 = df_time.get_group(2010)
 df_11 = df_time.get_group(2011)
 df_12 = df_time.get_group(2012)
 df_13 = df_time.get_group(2013) 
 df_14 = df_time.get_group(2014)
 df_15 = df_time.get_group(2015)

# %%
# plt.bar(df_10['LOCATION'], df_10['Value'])

# plt.bar(df_11['LOCATION'], df_11['Value'])
# plt.title('test')
# plt.show()
df_country.head()
# Out:
#    LOCATION INDICATOR   SUBJECT      MEASURE FREQUENCY  TIME      Value
# 0       CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9950.004
# 1       CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011  10000.179
# 2       CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012  10398.065
# 3       CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013  10535.674
# 4       CAN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014  10501.547
# 7       FIN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   8834.754
# 8       FIN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011   9271.955
# 9       FIN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012   9448.139
# 10      FIN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013   9658.920
# 11      FIN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014   9769.050
# 14      FRA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9265.066
# 15      FRA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011   9343.783
# 16      FRA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012   9312.157
# 17      FRA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013   9778.401
# 18      FRA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014   9918.340
# 21      DEU    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9203.307
# 22      DEU    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011   9613.138
# 23      DEU    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012   9821.053
# 24      DEU    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013  10300.284
# 25      DEU    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014  10779.232
# 28      JPN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   8885.861
# 29      JPN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011   9168.719
# 30      JPN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012   9563.784
# 31      JPN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013   9801.809
# 32      JPN    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014  10022.110
# 35      KOR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9122.943
# 36      KOR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011   9682.407
# 37      KOR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012  10343.851
# 38      KOR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013  10524.248
# 39      KOR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014  10803.948
# 42      MEX    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   2546.722
# 43      MEX    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011   2764.729
# 44      MEX    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012   2826.370
# 45      MEX    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013   2925.221
# 46      MEX    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014   3032.514
# 49      GBR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010   9431.662
# 50      GBR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011   9628.766
# 51      GBR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012   9966.511
# 52      GBR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013  11486.577
# 53      GBR    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014  11874.896
# 56      USA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2010  11814.530
# 57      USA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2011  11726.424
# 58      USA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2012  11742.520
# 59      USA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2013  11881.470
# 60      USA    EDUEXP  PRY_NTRY  USD_STUDENT         A  2014  12175.709

# %%
can_df = df_country.get_group('CAN')
fin_df = df_country.get_group('FIN')
fra_df = df_country.get_group('FRA')
deu_df = df_country.get_group('DEU')
jpn_df = df_country.get_group('JPN')
kor_df = df_country.get_group('KOR')
mex_df = df_country.get_group('MEX')
gbr_df = df_country.get_group('GBR')
usa_df = df_country.get_group('USA')

# %%
fig = plt.figure()
plt.rc('lines', linewidth=2, linestyle='-', marker='*')
 
plt.rcParams["figure.figsize"] = (11, 9)

 
plt.plot('TIME','Value', data = can_df, label = 'canada ')
plt.plot('TIME','Value', data = fin_df, label = 'finland')
plt.plot('TIME','Value', data = fra_df, label = 'france')
plt.plot('TIME','Value', data = deu_df, label = 'Germany')
plt.plot('TIME','Value', data = jpn_df, label = 'Japan')
plt.plot('TIME','Value', data = kor_df, label = 'Korea')
# plt.plot('TIME','Value', data = mex_df, label = 'Mexico')
plt.plot('TIME','Value', data = gbr_df, label = 'United kingdom')
plt.plot('TIME','Value', data = usa_df, label = 'United States')

plt.xlabel('years', fontsize =18)
plt.ylabel('Per Student cost', fontsize =18)
plt.title('Education Cost Per Student for Ten Cournty', fontsize =18)
plt.legend(ncol=2,loc="lower right", fontsize = 15)
plt.grid(b=True, which='major', color='#666666', linestyle='-')

plt.show()

# %%
print(mpld3.fig_to_html(fig, template_type="general"))
# Out:
# <style>
#
# </style>
#
# <div id="fig_el1574014257806372002179732082"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el1574014257806372002179732082", {"width": 792.0, "height": 648.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [2009.75, 2015.25], "ylim": [8655.2788, 12603.7332], "xdomain": [2009.75, 2015.25], "ydomain": [8655.2788, 12603.7332], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#666666", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 10, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#666666", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el157401425780635744", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el157401425783377480", "color": "#1F77B4", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el157401425783283608", "color": "#FF7F0E", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el157401425783283440", "color": "#2CA02C", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 4, "coordinates": "data", "id": "el157401425783427648", "color": "#D62728", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 5, "coordinates": "data", "id": "el157401425783428432", "color": "#9467BD", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 6, "coordinates": "data", "id": "el157401425783429216", "color": "#8C564B", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 7, "coordinates": "data", "id": "el157401425783430000", "color": "#E377C2", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 8, "coordinates": "data", "id": "el157401425783430784", "color": "#7F7F7F", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el157401425782844216", "color": "#1F77B4", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el157401425783471184", "color": "#FF7F0E", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 3, "coordinates": "axes", "id": "el157401425783509176", "color": "#2CA02C", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 4, "coordinates": "axes", "id": "el157401425783510240", "color": "#D62728", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 1, "coordinates": "axes", "id": "el157401425783511304", "color": "#9467BD", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 2, "coordinates": "axes", "id": "el157401425783512368", "color": "#8C564B", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 3, "coordinates": "axes", "id": "el157401425783558552", "color": "#E377C2", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "defa ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#          mpld3.draw_figure("fig_el1574014257806372002179732082", {"width": 792.0, "height": 648.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [2009.75, 2015.25], "ylim": [8655.2788, 12603.7332], "xdomain": [2009.75, 2015.25], "ydomain": [8655.2788, 12603.7332], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#666666", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 10, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#666666", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el157401425780635744", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el157401425783377480", "color": "#1F77B4", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el157401425783283608", "color": "#FF7F0E", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el157401425783283440", "color": "#2CA02C", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 4, "coordinates": "data", "id": "el157401425783427648", "color": "#D62728", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 5, "coordinates": "data", "id": "el157401425783428432", "color": "#9467BD", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 6, "coordinates": "data", "id": "el157401425783429216", "color": "#8C564B", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 7, "coordinates": "data", "id": "el157401425783430000", "color": "#E377C2", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 8, "coordinates": "data", "id": "el157401425783430784", "color": "#7F7F7F", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el157401425782844216", "color": "#1F77B4", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el157401425783471184", "color": "#FF7F0E", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 3, "coordinates": "axes", "id": "el157401425783509176", "color": "#2CA02C", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 4, "coordinates": "axes", "id": "el157401425783510240", "color": "#D62728", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 1, "coordinates": "axes", "id": "el157401425783511304", "color": "#9467BD", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 2, "coordinates": "axes", "id": "el157401425783512368", "color": "#8C564B", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 3, "coordinates": "axes", "id": "el157401425783558552", "color": "#E377C2", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "de ...
#       });
#     });
# }else{
#     // require.js not available: dynamically load d3 & mpld3
#     mpld3_load_lib("https://mpld3.github.io/js/d3.v3.min.js", function(){
#          mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.3.js", function(){
#
#                  mpld3.draw_figure("fig_el1574014257806372002179732082", {"width": 792.0, "height": 648.0, "axes": [{"bbox": [0.125, 0.125, 0.775, 0.755], "xlim": [2009.75, 2015.25], "ylim": [8655.2788, 12603.7332], "xdomain": [2009.75, 2015.25], "ydomain": [8655.2788, 12603.7332], "xscale": "linear", "yscale": "linear", "axes": [{"position": "bottom", "nticks": 8, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#666666", "dasharray": "none", "alpha": 1.0}, "visible": true}, {"position": "left", "nticks": 10, "tickvalues": null, "tickformat": null, "scale": "linear", "fontsize": 10.0, "grid": {"gridOn": true, "color": "#666666", "dasharray": "none", "alpha": 1.0}, "visible": true}], "axesbg": "#FFFFFF", "axesbgalpha": null, "zoomable": true, "id": "el157401425780635744", "lines": [{"data": "data01", "xindex": 0, "yindex": 1, "coordinates": "data", "id": "el157401425783377480", "color": "#1F77B4", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 2, "coordinates": "data", "id": "el157401425783283608", "color": "#FF7F0E", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 3, "coordinates": "data", "id": "el157401425783283440", "color": "#2CA02C", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 4, "coordinates": "data", "id": "el157401425783427648", "color": "#D62728", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 5, "coordinates": "data", "id": "el157401425783428432", "color": "#9467BD", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 6, "coordinates": "data", "id": "el157401425783429216", "color": "#8C564B", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 7, "coordinates": "data", "id": "el157401425783430000", "color": "#E377C2", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data01", "xindex": 0, "yindex": 8, "coordinates": "data", "id": "el157401425783430784", "color": "#7F7F7F", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 1, "coordinates": "axes", "id": "el157401425782844216", "color": "#1F77B4", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 2, "coordinates": "axes", "id": "el157401425783471184", "color": "#FF7F0E", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 3, "coordinates": "axes", "id": "el157401425783509176", "color": "#2CA02C", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 0, "yindex": 4, "coordinates": "axes", "id": "el157401425783510240", "color": "#D62728", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 1, "coordinates": "axes", "id": "el157401425783511304", "color": "#9467BD", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 2, "coordinates": "axes", "id": "el157401425783512368", "color": "#8C564B", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawstyle": "default"}, {"data": "data02", "xindex": 5, "yindex": 3, "coordinates": "axes", "id": "el157401425783558552", "color": "#E377C2", "linewidth": 2.0, "dasharray": "none", "alpha": 1, "zorder": 2000002.0, "drawsty ...
#             })
#          });
# }
# </script>

# %%
# g = sns.FacetGrid(data_new, row="TIME", margin_titles=True,  height=3, aspect=4)
#  g.map(plt.bar,"LOCATION" ,"Value", color="steelblue")
