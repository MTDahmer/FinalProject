# %%
# %matplotlib inline
import pandas as pd

import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import mpld3
mpld3.enable_notebook()


math= '../data/math_2010-2015.csv'
math_df =  pd.read_csv(math)
math_df.head(100)
# Out:
#    LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value  Flag Codes
# 0       CAN  PISAMATH     TOT  MEANSCORE         A  2012    518         NaN
# 1       CAN  PISAMATH     TOT  MEANSCORE         A  2015    516         NaN
# 2       FIN  PISAMATH     TOT  MEANSCORE         A  2012    519         NaN
# 3       FIN  PISAMATH     TOT  MEANSCORE         A  2015    511         NaN
# 4       FRA  PISAMATH     TOT  MEANSCORE         A  2012    495         NaN
# 5       FRA  PISAMATH     TOT  MEANSCORE         A  2015    493         NaN
# 6       DEU  PISAMATH     TOT  MEANSCORE         A  2012    514         NaN
# 7       DEU  PISAMATH     TOT  MEANSCORE         A  2015    506         NaN
# 8       JPN  PISAMATH     TOT  MEANSCORE         A  2012    536         NaN
# 9       JPN  PISAMATH     TOT  MEANSCORE         A  2015    532         NaN
# 10      KOR  PISAMATH     TOT  MEANSCORE         A  2012    554         NaN
# ...

# %%
Clean_math = math_df.drop(['Flag Codes'], axis=1)

# %%
# Clean_math.to_csv('../clean_data/math_10-15.csv', index=False)
Clean_math['TIME'] = Clean_math['TIME'].astype(object)

# %%
math_time = Clean_math.groupby(['TIME'])
math_country = Clean_math.groupby(['LOCATION'])

# %%
# can_df = math_country.get_group('CAN')
# fin_df = math_country.get_group('FIN')
# fra_df = math_country.get_group('FRA')
# deu_df = math_country.get_group('DEU')
# jpn_df = math_country.get_group('JPN')
# kor_df = math_country.get_group('KOR')
# mex_df = math_country.get_group('MEX')
# gbr_df = math_country.get_group('GBR')
# usa_df = math_country.get_group('USA')
# hkg_df = math_country.get_group('HKG')

# %%
 
 df_12 = math_time.get_group(2012)

 df_15 = math_time.get_group(2015)

# %%
df_12.head()
# Out:
#   LOCATION INDICATOR SUBJECT    MEASURE FREQUENCY  TIME  Value
# 0      CAN  PISAMATH     TOT  MEANSCORE         A  2012    518
# 2      FIN  PISAMATH     TOT  MEANSCORE         A  2012    519
# 4      FRA  PISAMATH     TOT  MEANSCORE         A  2012    495
# 6      DEU  PISAMATH     TOT  MEANSCORE         A  2012    514
# 8      JPN  PISAMATH     TOT  MEANSCORE         A  2012    536

# %%
 plt.bar(can_df['LOCATION'], can_df['Value'])

plt.bar(mex_df['LOCATION'], mex_df['Value'])
plt.title('test')
plt.show()

# %%
# fig = plt.figure()
# plt.rc('lines', linewidth=2, linestyle='-', marker='*')
 
# plt.rcParams["figure.figsize"] = (11, 9)

 
# plt.plot('TIME','Value', data = can_df, label = 'canada ')
# plt.plot('TIME','Value', data = fin_df, label = 'finland')
# plt.plot('TIME','Value', data = fra_df, label = 'france')
# plt.plot('TIME','Value', data = deu_df, label = 'Germany')
# plt.plot('TIME','Value', data = jpn_df, label = 'Japan')
# plt.plot('TIME','Value', data = kor_df, label = 'Korea')
# plt.plot('TIME','Value', data = mex_df, label = 'Mexico')
# plt.plot('TIME','Value', data = gbr_df, label = 'United kingdom')
# plt.plot('TIME','Value', data = usa_df, label = 'United States')
# plt.plot('TIME','Value', data = hkg_df, label = 'Hong Kong')

# plt.xticks(range(2012,2016))
# plt.xlabel('years', fontsize =18)
# plt.ylabel('Per Student cost', fontsize =18)
# plt.title('Education Cost Per Student for Ten Cournty', fontsize =18)
# plt.legend(ncol=2,loc="lower right", fontsize = 15)
# # plt.grid(b=True, which='major', color='#666666', linestyle='-')

# plt.show()

# %%
# print(mpld3.fig_to_html(fig, template_type="general"))
